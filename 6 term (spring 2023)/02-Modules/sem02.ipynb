# %% [markdown]
# #### Задача 1.
#
# Выполните эту ячейку. :)

# %%
import antigravity

# %% [markdown]
# #### Задача 2.
#
# Импортируйте библиотеку re (это стандартная библиотека питона). Посмотрите, какие у нее есть функции и переменные. Откройте (с помощью питона) документацию для функции findall.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Напишите скрипт в формате .py, в котором определите три функции:
#
# 1. Функция, которая проверяет, является ли строка кириллическим словом (можно использовать старый код); возвращает True или False
# 2. Функция, которая считывает текст из файла по пути path, делит его на слова и очищает от знаков препинания; возвращает список слов
# 3. Функция, которая принимает список слов и считает его лексическое разнообразие в процентах
#
# Импортируйте скрипт в новый файл (можно в тетрадку сюда: если вы работаете в колабе, нужно будет загрузить .py-файл в колаб), в котором нужно обработать любой текстовый файл и получить количество кириллических слов (таких, которые содержат только кириллические буквы и не содержат ни дефисов, ни других символов) и лексическое разнообразие.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Установите библиотеку [termcolor](https://pypi.org/project/termcolor/) или [colorama](https://pypi.org/project/colorama/). Попробуйте по документации разобраться, как она работает, и напишите скрипт, который будет открывать файл sentence.conllu, считывать из него разбор предложения и выводить следующим образом:
#
# - В файле каждый токен в предложении записан отдельной строчкой, разделенной знаками табуляции \t. Каждая строчка устроена одинаково, там есть:
#     1. порядковый номер токена
#     2. словоформа
#     3. лемма
#     4. часть речи UPOS (про этот формат мы с вами еще поговорим)
#     5. часть речи XPOS (в нашем файле - просто прочерк)
#     6. грамматические характеристики (фичи)
#     7. вершина зависимости (циферка)
#     8. вид синтаксической связи
#     9. глубинная позиция
#     10. семантический класс
# - нужно вывести в таком же виде, как в файле, но раскрасить цветами: 3, 4, 7-10. Цвета выбирайте какие понравятся.
#
# Возможно, чтобы было видно цвета, придется перезапустить среду разработки.

# %%
# your code here

# %% [markdown]
# #### Задача 5 (2 балла).
#
# Найдите библиотеку, которая бы позволила вам обрабатывать .docx файлы в питоне. Разберитесь с найденной библиотекой, прочитайте с ее помощью любой файл .docx. Напишите программу "конкорданс", которая будет открывать такой файл и искать по нему любые запросы пользователя, т.е., например, человек просит программу найти все вхождения последовательности символов "файл", а программа должна печатать N (это параметр - можно поручить выбирать его пользователю или задать в функции принта) строк длины M (это тоже параметр), в которых нашлась такая последовательность. Разделением текста на слова мы не занимаемся, только выводим строки, поэтому для поиска достаточно будет метода find.

# %%
# your code here
