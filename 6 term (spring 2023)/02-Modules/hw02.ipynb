# %% [markdown]
# #### Задача 1 (3 балла).
#
# Установите модуль wikipedia-api. Разберитесь в его документации. С помощью этого модуля соберите себе небольшой сборник статей Википедии: он может выглядеть как список словарей, где у каждого словаря есть ключ "название статьи" и "текст статьи". Итоговый сборник стоит записать в файл (лучше всего в машиночитаемом формате, но на худой конец обычный .txt сойдет). Какие статьи взять? Выберите себе страницу с категорией в Википедии, получите из нее все названия страниц этой категории (только осторожнее - страница может содержать вложенные категории) и выкачайте их в цикле.
#
# **Когда будете сдавать это задание, пришлите итоговый файл тоже.**
#
# Вам может пригодиться модуль time и его функция sleep: если вы будете слишком часто слать запросы в Википедию, она вас забанит на какое-то время. Используйте его так:

# %%
from time import sleep

sleep(1) # заставляет компьютер ничего не делать одну секунду

# %% [markdown]
# #### Задача 2 (2 балла).
#
# Установите себе библиотеку googletrans и разберитесь, как ее использовать. Осторожно: библиотека при установке без специальных параметров может не работать. Попробуйте самостоятельно найти решение проблемы, если работать не будет.
#
# Когда разберетесь с библиотекой, напишите программу, которая будет принимать от пользователя при запуске название языка-источника, языка-реципиента (на который переводим) и строчку для перевода.

# %%
# your code here
